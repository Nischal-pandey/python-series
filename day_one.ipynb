# %%
my_str =  "Nischal"
print(my_str[0:3])
# Out:
# Nis

# %%
my_str =  "Nischal"
print(my_str[-5:-1])
# Out:
# scha

# %%
s='rohitsharma'
s
# Out:
# 'rohitsharma'

# %%
s="rohit's father"
s
# Out:
# "rohit's father"

# %%
s[5]
# Out:
# "'"

# %%
s[-4]
# Out:
# 't'

# %%
s[0:-11]
# Out:
# 'roh'

# %%
s[2:-7]
# Out:
# "hit's"

# %%
s[2:11]
# Out:
# "hit's fat"

# %%
s[8:-6]
# Out:
# ''

# %%
s[-3:-11]
# Out:
# ''

# %%
s[-11:-3]
# Out:
# "it's fat"

# %%
s[-8:-15]
# Out:
# ''

# %%
s[0:5]
# Out:
# 'rohit'

# %%
s="rohit's sharma"
s
# Out:
# "rohit's sharma"

# %%
s[0::-1]
# Out:
# 'r'

# %%
s[0::1]
# Out:
# "rohit's sharma"

# %%
s[5:9:-1]
# Out:
# ''

# %%
s[3:16:2]
# Out:
# "i' hra"

# %%
s[::-3]
# Out:
# 'aa to'

# %%
print(s[-6:])
# Out:
# sharma

# %%
print(s[-6:-1])
# Out:
# sharm

# %%
print(s[-3:-11])

# %%
print(s[-10:-2:2])
# Out:
# tssa

# %%
s.upper()   #STRING MEHTODS
# Out:
# "ROHIT'S SHARMA"

# %%
s="roh5645it"
s.upper()
# Out:
# 'ROH5645IT'

# %%
s.lower()
# Out:
# 'roh5645it'

# %%
s="rohit"
s.capitalize()
# Out:
# 'Rohit'

# %%
s="555roj"
s.capitalize()
# Out:
# '555roj'

# %%
s.title()
# Out:
# '555Roj'

# %%
s="Nischal"
s.index('a')
# Out:
# 5

# %%
s.index('y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 s.index('y')
#
# ValueError: substring not found

# %%
s.find('y')
# Out:
# -1

# %%
s="rohit8555SHAEMA"
s.swapcase()
# Out:
# 'ROHIT8555shaema'

# %%
s.count('A')
# Out:
# 2

# %%
s="rohit sharma"
len(s)
# Out:
# 12

# %%
s.strip()
# Out:
# 'rohit sharma'

# %%
s.split('h')
# Out:
# ['ro', 'it s', 'arma']

# %%
s.partition('h')
# Out:
# ('ro', 'h', 'it sharma')

# %%
s.partition('r')
# Out:
# ('', 'r', 'ohit sharma')

# %%
s.replace('s','r')
# Out:
# 'rohit rharma'

# %%
s="Nischal"
s[0]
# Out:
# 'N'

# %%
s[0]=='i'
# Out:
# False

# %%
s[0]=='N'
# Out:
# True

# %%
s.startswith('N')
# Out:
# True

# %%
s.endswith('l')
# Out:
# True

# %%
s="4"
r=5
s+r
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 s="4"
#       2 r=5
# ----> 3 s+r
#
# TypeError: can only concatenate str (not "int") to str

# %%
s="5"
r="55"
s+r
# Out:
# '555'

# %%
name="gulshan"
age=27
ht=170.5
wt=70
mob=6+5j
print("{} {} {} {} {}".format(name,age,ht,wt,mob))
# Out:
# gulshan 27 170.5 70 (6+5j)

# %%
name="Nischal Pandey"
age=21
ht=170.5
wt=80
mob=6+5j
print(f"hello gys my name is {name} and my age is {age} also my ht is {ht} wt is {wt} and my mobile number is {mob}")
# Out:
# hello gys my name is Nischal Pandey and my age is 21 also my ht is 170.5 wt is 80 and my mobile number is (6+5j)

# %%
#Boolean

# %%
bool()
# Out:
# False

# %%
bool(5)
# Out:
# True

# %%
bool(-5)
# Out:
# True

# %%
bool(566.8888)
# Out:
# True

# %%
bool(1)
# Out:
# True

# %%
bool(5+6)
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool(' ')
# Out:
# True

# %%
bool(True)
# Out:
# True

# %%
bool(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 bool(true)
#
# NameError: name 'true' is not defined

# %%
bool(False)
# Out:
# False

# %%
bool(false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 bool(false)
#
# NameError: name 'false' is not defined

# %%
bool('true')
# Out:
# True

# %%
bool('false')
# Out:
# True

# %%
bool('None')
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool('0')
# Out:
# True

# %%
# LIST

# %%
s=((34,55,44,85,63,14))
s
# Out:
# (34, 55, 44, 85, 63, 14)

# %%
s=((34,55,44,85,63,14,"tom",6+5J))
s
# Out:
# (34, 55, 44, 85, 63, 14, 'tom', (6+5j))

# %%
type(s)
# Out:
# tuple

# %%
s=[34,56,32,25,98,"tom",(5+6j)]
s
# Out:
# [34, 56, 32, 25, 98, 'tom', (5+6j)]

# %%
type(s)
# Out:
# list

# %%
s[1]
# Out:
# 56

# %%
s[1:4]
# Out:
# [56, 32, 25]

# %%
# ADIING ELEMENT WITHOUT REPLACING
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
s=((34,55,44,85,63,14,"tom",6+5J))
s
# Out:
# (34, 55, 44, 85, 63, 14, 'tom', (6+5j))

# %%
r=[34, 89.25, 67, 23, 90, 34, 89, 'tom', (6+5j)]
r
# Out:
# [34, 89.25, 67, 23, 90, 34, 89, 'tom', (6+5j)]
