# %%
import pandas as pd
import numpy as np

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="dark")

#simulate data from a bivariate gaussain
n=10000
mean = [0, 0]
cov = [(2, .4), (.4, .2)]
rng = np.random.RandomState(0)
x, y = rng.multivariate_normal(mean, cov, n).T

# Draw a combo histogram and scatterplot with density contours
f, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=x, y=y, s=5, color=".15")
sns.histplot(x=x, y=y, bins=50, pthresh=.1, cmap="mako")
sns.kdeplot(x=x, y=y, levels=5, color="w", lineswidths=1)
# Out:
# C:\Users\Nischal pandey\anaconda3\Lib\site-packages\seaborn\distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'lineswidths'
#   cset = contour_func(
# <Axes: >

# %%
import seaborn as sns
sns.set_theme(style="dark")

#load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(data=tips, x="day", y="total_bill", hue="smoker",
               split=True, inner="quart", fill=False,
               palette={"Yes": "g", "No": ".35"})
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df2=pd.read_csv('sales_details.csv')
df2.tail()
# Out:
#        Order ID   OrderDate  Customer Name Index     Channel Currency Code  \
# 10679     21679  05-06-2020                  122  Industries          Euro
# 10680     21680  05-06-2020                  165      Import          Euro
# 10681     21681  05-06-2020                   86  Industries          Euro
# 10682     21682  05-06-2020                   43      Import          Euro
# 10683     21683  05-06-2020                  165  Industries          Euro
#
#            Code  Region ID  Product ID  Quantity  Unit Price   Unit Cost
# 10679  NVG256YT         56           3         7       261.3     107.133
# 10680  NVG256YT         33          28         7      1996.6    1477.484
# 10681  NVG256YT         41          16         9      3912.8    2817.216
# 10682  NVG256YT         15          13        10      1855.9    1113.540
# 10683  NVG256YT         64          16        11      3959.7    2138.238

# %%
df3=pd.read_csv(r"C:\Users\Nischal pandey\Desktop\python notes\udemy_courses.csv")
df3.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration   published_timestamp           subject
# 0               1.5  2017-01-18T20:58:58Z  Business Finance
# 1              39.0  2017-03-09T16:34:20Z  Business Finance
# 2               2.5  2016-12-19T19:26:30Z  Business Finance
# 3               3.0  2017-05-30T20:07:24Z  Business Finance
# 4               2.0  2016-12-13T14:57:18Z  Business Finance

# %%
df3.shape
# Out:
# (3678, 12)

# %%
df3.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df3.info
# Out:
# <bound method DataFrame.info of       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# 1         https://www.udemy.com/goods-and-services-tax/     True     75
# 2     https://www.udemy.com/financial-modeling-for-b...     True     45
# 3     https://www.udemy.com/complete-excel-finance-c...     True     95
# 4     https://www.udemy.com/how-to-maximize-your-pro...     True    200
# ...                                                 ...      ...    ...
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures               level  \
# 0                2147           23            51          All Levels
# 1                2792          923           274          All Levels
# 2                2174           74            51  Intermediate Level
# 3                2451           11            36          All Levels
# 4                1276           45            26  Intermediate Level
# ...               ...          ...           ...                 ...
# 3673             1040           14            21          All Levels
# 3674              306            3            42      Beginner Level
# 3675              513          169            48          All Levels
# 3676              300           31            38          All Levels
# 3677              901           36            20      Beginner Level
#
#       content_duration   published_timestamp           subject
# 0                  1.5  2017-01-18T20:58:58Z  Business Finance
# 1                 39.0  2017-03-09T16:34:20Z  Business Finance
# 2                  2.5  2016-12-19T19:26:30Z  Business Finance
# 3                  3.0  2017-05-30T20:07:24Z  Business Finance
# 4                  2.0  2016-12-13T14:57:18Z  Business Finance
# ...                ...                   ...               ...
# 3673               2.0  2016-06-14T17:36:46Z   Web Development
# 3674               3.5  2017-03-10T22:24:30Z   Web Development
# 3675               3.5  2015-12-30T16:41:42Z   Web Development
# 3676               3.0  2016-08-11T19:06:15Z   Web Development
# 3677               2.0  2014-09-28T19:51:11Z   Web Development
#
# [3678 rows x 12 columns]>

# %%
df3.describe
# Out:
# <bound method NDFrame.describe of       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# 1         https://www.udemy.com/goods-and-services-tax/     True     75
# 2     https://www.udemy.com/financial-modeling-for-b...     True     45
# 3     https://www.udemy.com/complete-excel-finance-c...     True     95
# 4     https://www.udemy.com/how-to-maximize-your-pro...     True    200
# ...                                                 ...      ...    ...
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures               level  \
# 0                2147           23            51          All Levels
# 1                2792          923           274          All Levels
# 2                2174           74            51  Intermediate Level
# 3                2451           11            36          All Levels
# 4                1276           45            26  Intermediate Level
# ...               ...          ...           ...                 ...
# 3673             1040           14            21          All Levels
# 3674              306            3            42      Beginner Level
# 3675              513          169            48          All Levels
# 3676              300           31            38          All Levels
# 3677              901           36            20      Beginner Level
#
#       content_duration   published_timestamp           subject
# 0                  1.5  2017-01-18T20:58:58Z  Business Finance
# 1                 39.0  2017-03-09T16:34:20Z  Business Finance
# 2                  2.5  2016-12-19T19:26:30Z  Business Finance
# 3                  3.0  2017-05-30T20:07:24Z  Business Finance
# 4                  2.0  2016-12-13T14:57:18Z  Business Finance
# ...                ...                   ...               ...
# 3673               2.0  2016-06-14T17:36:46Z   Web Development
# 3674               3.5  2017-03-10T22:24:30Z   Web Development
# 3675               3.5  2015-12-30T16:41:42Z   Web Development
# 3676               3.0  2016-08-11T19:06:15Z   Web Development
# 3677               2.0  2014-09-28T19:51:11Z   Web Development
#
# [3678 rows x 12 columns]>

# %%
df3.describe(include="all")
# Out:
#            course_id                                       course_title  \
# count   3.678000e+03                                               3678
# unique           NaN                                               3663
# top              NaN  Creating an animated greeting card via Google ...
# freq             NaN                                                  3
# mean    6.759720e+05                                                NaN
# std     3.432732e+05                                                NaN
# min     8.324000e+03                                                NaN
# 25%     4.076925e+05                                                NaN
# 50%     6.879170e+05                                                NaN
# 75%     9.613555e+05                                                NaN
# max     1.282064e+06                                                NaN
#
#                                                       url is_paid  \
# count                                                3678    3678
# unique                                               3672       2
# top     https://www.udemy.com/understanding-financial-...    True
# freq                                                    2    3368
# mean                                                  NaN     NaN
# std                                                   NaN     NaN
# min                                                   NaN     NaN
# 25%                                                   NaN     NaN
# 50%                                                   NaN     NaN
# 75%                                                   NaN     NaN
# max                                                   NaN     NaN
#
#               price  num_subscribers   num_reviews  num_lectures       level  \
# count   3678.000000      3678.000000   3678.000000   3678.000000        3678
# unique          NaN              NaN           NaN           NaN           4
# top             NaN              NaN           NaN           NaN  All Levels
# freq            NaN              NaN           NaN           NaN        1929
# mean      66.049483      3197.150625    156.259108     40.108755         NaN
# std       61.005755      9504.117010    935.452044     50.383346         NaN
# min        0.000000         0.000000      0.000000      0.000000         NaN
# 25%       20.000000       111.000000      4.000000     15.000000         NaN
# 50%       45.000000       911.500000     18.000000     25.000000         NaN
# 75%       95.000000      2546.000000     67.000000     45.750000         NaN
# max      200.000000    268923.000000  27445.000000    779.000000         NaN
#
#         content_duration   published_timestamp          subject
# count        3678.000000                  3678             3678
# unique               NaN                  3672                4
# top                  NaN  2016-12-15T14:56:17Z  Web Development
# freq                 NaN                     2             1200
# mean            4.094517                   NaN              NaN
# std             6.053840                   NaN              NaN
# min             0.000000                   NaN              NaN
# 25%             1.000000                   NaN              NaN
# 50%             2.000000                   NaN              NaN
# 75%             4.500000                   NaN              NaN
# max            78.500000                   NaN              NaN

# %%
df3.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
df3.duplicated().sum()
# Out:
# np.int64(6)

# %%
df3.drop_duplicates(inplace=True)

# %%
df3.duplicated().sum()
# Out:
# np.int64(0)

# %%
import numpy as np
import pandas as pd

# %%
dict1 ={'Name':['Priyang','Aadhya','Krishna','Vedant','parshv',
                'Mittal','Archana'],
        'marks':[98,np.nan,99,87,np.nan,83,99],
        'Gender':['Male','Female','Female','Male','Male',
                         'Female','Female'],
                'Email':['priyang@gmail.com','aadhya@gmail.com',
                        'krisha@gmail.com','vedant@yahoo.com','parshv@hotmail.com',
                         'mittal@yahoo.com','archana@yahoo.com']
               }
df1=pd.DataFrame(dict1)
df1
# Out:
#       Name  marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2  Krishna   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
# 1. top 3 rows of the dataset

# %%
df1.head(3)
# Out:
#       Name  marks  Gender              Email
# 0  Priyang   98.0    Male  priyang@gmail.com
# 1   Aadhya    NaN  Female   aadhya@gmail.com
# 2  Krishna   99.0  Female   krisha@gmail.com

# %%
df1.tail()
# Out:
#       Name  marks  Gender               Email
# 2  Krishna   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
# All rows except the last 2 rows

# %%
df1.head(-2)
# Out:
#       Name  marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2  Krishna   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   parshv    NaN    Male  parshv@hotmail.com

# %%
# all rows except the first 3 rows

# %%
df1.tail(-3)
# Out:
#       Name  marks  Gender               Email
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
# find the shape of our datasetset

# %%
df1.shape
# Out:
# (7, 4)

# %%
print ("Numbers of Rows",df1.shape[0])
print("Number of Columns",df1.shape[1])
# Out:
# Numbers of Rows 7
# Number of Columns 4

# %%
df1
# Out:
#       Name  marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2  Krishna   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   marks   5 non-null      float64
#  2   Gender  7 non-null      object
#  3   Email   7 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 356.0+ bytes

# %%
# check null values in our dataset

# %%
df1.isnull().sum()
# Out:
# Name      0
# marks     2
# Gender    0
# Email     0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
# get overall statistics about the dataset

# %%
df1.describe()
# Out:
#            marks
# count   5.000000
# mean   93.200000
# std     7.628892
# min    83.000000
# 25%    87.000000
# 50%    98.000000
# 75%    99.000000
# max    99.000000

# %%
df1.describe(include='all')
# Out:
#            Name      marks  Gender              Email
# count         7   5.000000       7                  7
# unique        7        NaN       2                  7
# top     Priyang        NaN  Female  priyang@gmail.com
# freq          1        NaN       4                  1
# mean        NaN  93.200000     NaN                NaN
# std         NaN   7.628892     NaN                NaN
# min         NaN  83.000000     NaN                NaN
# 25%         NaN  87.000000     NaN                NaN
# 50%         NaN  98.000000     NaN                NaN
# 75%         NaN  99.000000     NaN                NaN
# max         NaN  99.000000     NaN                NaN

# %%
# find the unique values from the gender column

# %%
df1.columns
# Out:
# Index(['Name', 'marks', 'Gender', 'Email'], dtype='object')

# %%
df1['Name'].unique()
# Out:
# array(['Priyang', 'Aadhya', 'Krishna', 'Vedant', 'parshv', 'Mittal',
#        'Archana'], dtype=object)

# %%
#3 find the number of unique values from the gender column

# %% [markdown]
# df1

# %%
df1
# Out:
#       Name  marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2  Krishna   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df1.nunique()
# Out:
# Name      7
# marks     4
# Gender    2
# Email     7
# dtype: int64

# %%
# Display count of unique values in gender column

# %%
df1['Gender'].value_counts()
# Out:
# Gender
# Female    4
# Male      3
# Name: count, dtype: int64

# %%
df1
# Out:
#       Name  marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2  Krishna   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
# handling missing values

# %%
df1.dropna(how='all')
# Out:
#       Name  marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2  Krishna   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df1
# Out:
#       Name  marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2  Krishna   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df1.fillna(0)
# Out:
#       Name  marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    0.0  Female    aadhya@gmail.com
# 2  Krishna   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   parshv    0.0    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df1['Marks']=df1['Marks'].fillna(df1['Marks'].mean())

# %%
df1
# Out:
#       Name  marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2  Krishna   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
# marks between 80 to 90

# %%
df1
# Out:
#       Name  marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2  Krishna   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df1.columns
# Out:
# Index(['Name', 'marks', 'Gender', 'Email'], dtype='object')

# %%
df1.nlargest(5,'marks')[['Name','marks']]
# Out:
#       Name  marks
# 2  Krishna   99.0
# 6  Archana   99.0
# 0  Priyang   98.0
# 3   Vedant   87.0
# 5   Mittal   83.0

# %%
df1.sort_values(by='marks',ascending=False).head()[['Name','marks']]
# Out:
#       Name  marks
# 2  Krishna   99.0
# 6  Archana   99.0
# 0  Priyang   98.0
# 3   Vedant   87.0
# 5   Mittal   83.0

# %%
# Find Avg marks

# %%
 df1
# Out:
#       Name  marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2  Krishna   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df1['marks'].mean()
# Out:
# np.float64(93.2)

# %%
df1['marks'].min()
# Out:
# 83.0

# %%
df1['marks'].max()
# Out:
# 99.0

# %%
# Apply method

# %%
df1
# Out:
#       Name  marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2  Krishna   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
def marks(x):
    return x//2

# %%
df1['Half_marks']=df1['marks'].apply(marks)

# %%
df1
# Out:
#       Name  marks  Gender               Email  Half_marks
# 0  Priyang   98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya    NaN  Female    aadhya@gmail.com         NaN
# 2  Krishna   99.0  Female    krisha@gmail.com        49.0
# 3   Vedant   87.0    Male    vedant@yahoo.com        43.0
# 4   parshv    NaN    Male  parshv@hotmail.com         NaN
# 5   Mittal   83.0  Female    mittal@yahoo.com        41.0
# 6  Archana   99.0  Female   archana@yahoo.com        49.0

# %%
# map function

# %%
df1
# Out:
#       Name  marks  Gender               Email  Half_marks
# 0  Priyang   98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya    NaN  Female    aadhya@gmail.com         NaN
# 2  Krishna   99.0  Female    krisha@gmail.com        49.0
# 3   Vedant   87.0    Male    vedant@yahoo.com        43.0
# 4   parshv    NaN    Male  parshv@hotmail.com         NaN
# 5   Mittal   83.0  Female    mittal@yahoo.com        41.0
# 6  Archana   99.0  Female   archana@yahoo.com        49.0

# %%
df1['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df1['Male_Female']=df1['Gender'].map({'Male' :1,'Female':0})

# %%
df1
# Out:
#       Name  marks  Gender               Email  Half_marks  Male_Female
# 0  Priyang   98.0    Male   priyang@gmail.com        49.0            1
# 1   Aadhya    NaN  Female    aadhya@gmail.com         NaN            0
# 2  Krishna   99.0  Female    krisha@gmail.com        49.0            0
# 3   Vedant   87.0    Male    vedant@yahoo.com        43.0            1
# 4   parshv    NaN    Male  parshv@hotmail.com         NaN            1
# 5   Mittal   83.0  Female    mittal@yahoo.com        41.0            0
# 6  Archana   99.0  Female   archana@yahoo.com        49.0            0
